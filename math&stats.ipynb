# %%
from sympy import symbols
from sympy.plotting import plot

x = symbols('x')
f = 2*x+1
plot(f)

# %%
x = symbols('x')
f = x**3+15*x+300
plot(f)

# %%
7**5
# Out:
# 16807

# %%
2**2/2**5
# Out:
# 0.125

# %%
sqrt(16)
# Out:
# 4.0

# %%
from math import log
x = log(8,2)
print(x)
# Out:
# 3.0

# %%
16807**(1/5)
# Out:
# 7.000000000000001
